# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/programs.csv")

# %%
df.head()
# Out:
#    id  college_id               program_name duration          college_name
# 0   1         161                MSc Physics  2 Years  Amrit Science Campus
# 1   2         161                MSc Physics  2 Years  Amrit Science Campus
# 2   3         161                MSc Physics  2 Years  Amrit Science Campus
# 3   4         161                MSc Physics      NaN  Amrit Science Campus
# 4   5         161  BSc Environmental Science  4 Years  Amrit Science Campus

# %%
df.isna()
# Out:
#          id  college_id  program_name  duration  college_name
# 0     False       False         False     False         False
# 1     False       False         False     False         False
# 2     False       False         False     False         False
# 3     False       False         False      True         False
# 4     False       False         False     False         False
# ...     ...         ...           ...       ...           ...
# 2227  False       False         False     False         False
# 2228  False       False         False      True         False
# 2229  False       False         False     False         False
# 2230  False       False         False     False         False
# 2231  False       False         False      True         False
#
# [2232 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2232 entries, 0 to 2231
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            2232 non-null   int64
#  1   college_id    2232 non-null   int64
#  2   program_name  2232 non-null   object
#  3   duration      1525 non-null   object
#  4   college_name  2232 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 87.3+ KB

# %%
df.drop_duplicates(inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2232 entries, 0 to 2231
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            2232 non-null   int64
#  1   college_id    2232 non-null   int64
#  2   program_name  2232 non-null   object
#  3   duration      1525 non-null   object
#  4   college_name  2232 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 87.3+ KB

# %%
df.dropna()
# Out:
#         id  college_id                                       program_name  \
# 0        1         161                                        MSc Physics
# 1        2         161                                        MSc Physics
# 2        3         161                                        MSc Physics
# 4        5         161                          BSc Environmental Science
# 5        6         161                          BSc Environmental Science
# ...    ...         ...                                                ...
# 2224  2225         387                     Bachelor of Arts in Psychology
# 2226  2227         387  Bachelor of Arts in Journalism and Mass Commun...
# 2227  2228         387  Bachelor of Arts in Journalism and Mass Commun...
# 2229  2230         387    BSc Computer Science and Information Technology
# 2230  2231         387    BSc Computer Science and Information Technology
#
#      duration          college_name
# 0     2 Years  Amrit Science Campus
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2232 entries, 0 to 2231
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            2232 non-null   int64
#  1   college_id    2232 non-null   int64
#  2   program_name  2232 non-null   object
#  3   duration      1525 non-null   object
#  4   college_name  2232 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 87.3+ KB

# %%
df.isnull()
# Out:
#          id  college_id  program_name  duration  college_name
# 0     False       False         False     False         False
# 1     False       False         False     False         False
# 2     False       False         False     False         False
# 3     False       False         False      True         False
# 4     False       False         False     False         False
# ...     ...         ...           ...       ...           ...
# 2227  False       False         False     False         False
# 2228  False       False         False      True         False
# 2229  False       False         False     False         False
# 2230  False       False         False     False         False
# 2231  False       False         False      True         False
#
# [2232 rows x 5 columns]

# %%
df.dropna(inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1525 entries, 0 to 2230
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1525 non-null   int64
#  1   college_id    1525 non-null   int64
#  2   program_name  1525 non-null   object
#  3   duration      1525 non-null   object
#  4   college_name  1525 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 71.5+ KB

# %%
df[df.duplicated(subset=["college_id", "program_name", "duration"], keep = False) ]
# Out:
#         id  college_id                                       program_name  \
# 0        1         161                                        MSc Physics
# 1        2         161                                        MSc Physics
# 2        3         161                                        MSc Physics
# 4        5         161                          BSc Environmental Science
# 5        6         161                          BSc Environmental Science
# ...    ...         ...                                                ...
# 2224  2225         387                     Bachelor of Arts in Psychology
# 2226  2227         387  Bachelor of Arts in Journalism and Mass Commun...
# 2227  2228         387  Bachelor of Arts in Journalism and Mass Commun...
# 2229  2230         387    BSc Computer Science and Information Technology
# 2230  2231         387    BSc Computer Science and Information Technology
#
#      duration          college_name
# 0     2 Years  Amrit Science Campus
# ...

# %%
df.drop_duplicates(subset=["college_id", "program_name", "duration"], keep = "first", inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 702 entries, 0 to 2229
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            702 non-null    int64
#  1   college_id    702 non-null    int64
#  2   program_name  702 non-null    object
#  3   duration      702 non-null    object
#  4   college_name  702 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 32.9+ KB

# %%
df.head()
# Out:
#     id  college_id               program_name duration          college_name
# 0    1         161                MSc Physics  2 Years  Amrit Science Campus
# 4    5         161  BSc Environmental Science  4 Years  Amrit Science Campus
# 7    8         161           BSc Microbiology  4 Years  Amrit Science Campus
# 10  11         161                BSc Physics  4 Years  Amrit Science Campus
# 13  14         161    MSc Applied Mathematics  2 Years  Amrit Science Campus

# %%
df.sample(50)
# Out:
#         id  college_id                                       program_name  \
# 457    458         204                         Master of Business Studies
# 1993  1994         372                            Ten Plus Two Humanities
# 1188  1189         290                       Bachelor of Hotel Management
# 2214  2215         387      Bachelor of Information Technology Management
# 1386  1386         300                            GCE A Level Non-Science
# 161    162         171                               Ten Plus Two Science
# 2047  2048         376                Bachelor of Business Administration
# 1201  1202         290                    Bachelor of Arts in Social Work
# 69      70         164    BSc Computer Science and Information Technology
# 682    683         229                   Bachelor of Computer Application
# 321    321         187  MS Clinical Otorhinolaryngology and Head and N...
# 860    861         258                       Bachelor of Business Studies
# ...

# %%
df.to_csv("cleaned_programs.csv", index = False)
